# %% [markdown]
# # Read in data to sort

# %%
import json

# inputData = {}
inputData = []

with open('testData.json', 'r') as f:
    data = json.load(f)

print(data)
# Out:
# [['0', ['l', 'e', 'f', 't', 'i', 'k', 'v', 'p', 'd', 'q', 'r', 'a', 'g', 'g', 's', 'd', 'c', 'e', 'c', '!', 'a', 'g', 'p', 'g', 'k', 'r', '!', 'i', 't', 'i', 'v', 'e', 'v', 's'], 64], ['3', ['l', 'e', 'f', 't', 'i', 'k', 'v', 'p', 'd', 'q', 'r', 'a', 'g', 'g', 's', 'd', 'c', 'e', 'c', '!', 'a', 'g', 'p', 'g', 'k', 'r', '!', 'i', 't', 'i', 'v', 'e', 'v', 's'], 64], ['6', ['l', 'e', 'f', 't', 'i', 'k', 'v', 'p', 'e', 'q', 'r', 'a', 'g', 'g', 's', 'd', 'c', 'e', 'c', '!', 'a', 'g', 'p', 'g', 'k', 'r', '!', 'i', 't', 'i', 'v', 'e', 'v', 's'], 64], ['9', ['l', 'e', 'f', 't', 't', 'k', 'v', 'p', 'd', 'q', 'r', 'a', 'g', 'g', 's', 'd', 'c', 'e', 'c', '!', 'a', 'g', 'p', 'g', 'k', 'p', 's', 'i', 't', 'i', 'v', 'e', 'v', 's'], 64], ['12', ['l', 'e', 'f', 't', 'i', 'k', 'v', 'p', 'e', 'q', 'r', 'a', 'g', 'g', 's', 'd', 'c', 'e', 'c', '!', 'a', 'g', 'p', 'g', 'k', 'r', '!', 'i', 't', 'i', 'v', 'e', 'v', 's'], 64], ['15', ['l', 'e', 'f', 't', 'i', 'k', 'v', 'p', 'v', 'q', 'r', 'a', 'g', 'g', 's', 'd', 'c', 'e', 'c', '!', 'a', 'g', 'p', 'g', 'k', 'r', '!', 'i', 't', 'i', 'v', 'e', 'v', 's'], 72], ['18', ['l', 'e', 'f', 't', 'i', 'k', 'v', 'p', 'v', 'q', 'r', 'a', 'g', 'g', 's', 'd', 'c', 'e', 'c', '!', 'a', 'g', 'p', 'g', 'k', 'r', '!', 'i', 't', 'i', 'v', 'e', 'v', 's'], 72], ['21', ['m', 'e', 'f', 't', 'i', 'k', 'v', 'p', 'v', 'q', 'r', 'a', 'g', 'g', 's', 'd', 'c', 'e', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', '!', 'i', 't', 'i', 'v', 'e', 'v', 's'], 82], ['24', ['l', 'e', 'f', 't', 'i', 'k', 'v', 'p', 'v', 'q', 'r', 'p', 'g', 'g', 's', 'd', 'c', 'e', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', '!', 'i', 't', 'i', 'v', 'e', 'v', 's'], 88], ['27', ['l', 'e', 'f', 't', 'i', 'k', 'v', 'p', 'v', 'q', 'r', 'p', 'g', 'g', 's', 'd', 'c', 'd', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', '!', 'i', 't', 'i', 'v', 'e', 'v', 's'], 96], ['30', ['l', 'e', 'f', 't', 'i', 'k', 'v', 'p', 'v', 'q', 'r', 'p', 'g', 'g', 's', 'd', 'c', 'd', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', '!', 'i', 't', 'i', 'v', 'e', 'v', 's'], 96], ['33', ['l', 'd', 'f', 't', 'i', 'k', 'v', 'p', 'v', 'q', 'r', 's', 'g', 'g', 's', 'd', 'c', 'd', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', 'e', 'i', 't', 'i', 'v', 'e', 'v', 's'], 104], ['36', ['l', 'd', 'f', 't', 'i', 'k', 'v', 'p', 'v', 'q', 'r', 'p', 'g', 'g', 's', 'd', 'c', 'd', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', '!', 'i', 't', 'i', 'v', 'e', 'v', 's'], 104], ['39', ['l', 'd', 'f', 't', 'i', 'k', 'v', 'p', 'v', 'q', 'r', 'p', 'g', 'g', 's', 'd', 'c', 'd', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', 'e', 'i', 't', 'i', 'v', 'e', 'v', 's'], 104], ['42', ['l', 'd', 'f', 't', 'i', 'k', 'v', 'p', 'm', 'q', 'r', 'p', 'g', 'r', 's', 'd', 'c', 'd', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', 'e', 'i', 't', 'v', 'v', 'e', 'v', 's'], 114], ['45', ['l', 'd', 'f', 't', 'i', 'k', 'v', 'p', 'm', 'q', 'r', 'p', 'g', 'r', 's', 'd', 'c', 'd', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', 'e', 'i', 't', 'i', 'v', 'e', 'v', 's'], 122], ['48', ['l', 'd', 'f', 't', 'i', 'k', 'v', 'p', 'm', 'q', 'r', 'p', 'g', 'r', 's', 'd', 'w', 'd', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', 'e', 'i', 't', 'i', 'v', 'e', 'v', 's'], 130], ['51', ['l', 'd', 'f', 't', 'i', 'k', 'v', 'p', 'm', 'q', 'r', 'p', 'g', 'r', 's', 'd', 'w', 'd', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', 'e', 'i', 't', 'i', 'v', 'e', 'v', 's'], 130], ['54', ['l', 'd', 'f', 't', 'i', 'k', 'v', 'p', 'm', 'q', 'r', 'p', 'g', 'r', 's', 'd', 'w', 'd', 'w', '!', 'a', 'g', 'p', 'g', 'k', 'r', 'e', 'i', 't', 'n', 'v', 'e', 'v', 's'], 132], ['57', ['l', 'd', 'f', 't', 'i', 'k', 'v', 'p', 'm', 'q', 'r', 'p', 'g', 'r', 's', 'd', 'w', 'd', 'w', '!', 'a', 'a', 'p', 'g', 'k', 'r', 'e', 'i', 't', 'i', 'v', 'e', 'v', 's'], 146], ['60', ['l', 'd', 'f', 't', 'i', 'k', 'v', 'p', 'm', 'p', 'r', 'p', 'g', 'r', 's', 'd', 'w', 'd', 'w', '!', 'a', 'a', 'p', 'g', 'k', 'r', 'e', 'i', 't', 'i', 'v', 'e', 'v', 's'], 146], ['63', ['l', 'd', 'f', 't', 'i', 'k', 'v', 'p', 'm', 'p', 'r', 'p', 'g', 'r', 's', 'd', 'w', 'd', 'w', '!', 'a', 'a', 'p', 'g', ' ...

# %% [markdown]
# Given the most recent individual, we will attempt to construct an evolutionary history.

# %%
newest_individual = data[-1]
oldest_individual = data[0]
print(newest_individual)
# Out:
# ['1998', ['r', 'y', 'a', '!', 'm', 'h', 'a', 'c', 'm', 't', 'r', 'h', 'm', 'n', 'v', 'c', 'm', 'n', 'e', '!', 'm', 'y', 'v', 'w', 'm', 'n', 'e', 'w', 'k', 'y', 'a', 'l', 'm', 'i'], 228]

# %%
import GenomeAligner

genomeLength = len(data[0][1])

ga = GenomeAligner.GenomeAligner(genomeLength, genomeLength)

print(ga.calc)
